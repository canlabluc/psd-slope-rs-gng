# %% [markdown]
# ## importing our files using scipy

# %%
# %matplotlib inline

import scipy as sp
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import os
import scipy.io
import scipy.signal

# %%
data = sp.io.loadmat('/Users/jorge/Dropbox/research/_psd-slope/data/extClfiltCAR-mat/120127101.mat')

name  = np.squeeze(data['name'])
srate = np.squeeze(data['srate'])
data  = np.squeeze(data['data'])

# %%
print(srate)
print(name)
print(data[0])
# Out:
# 512
# 120127101
# [  2.14064693   1.39466      0.55044603 ..., -11.54485321 -10.77541065
#  -10.10836983]

# %%
plt.plot(data[0][0:512])

# %%
f, psd = sp.signal.welch(data[0][0:5000], fs=srate, nperseg=srate*2, window='hanning')
plt.plot(f[0:513], psd[0:513])

# %%
plt.plot(psd)

# %%
f[70]
# Out:
# 35.0

# %%
f
# Out:
# array([[-0. , -0.5, -1. , ...,  1.5,  1. ,  0.5]])

# %%
plt.plot(psd)

# %%
plt.plot(f[0:50], np.log10(psd[0:50]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-674b49f1abbd> in <module>()
# ----> 1 plt.plot(f[0:50], np.log10(psd[0:50]))
#
# /Users/jorge/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# /Users/jorge/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# ...

# %%
f[0]
# Out:
# array([-0. , -0.5, -1. , ...,  1.5,  1. ,  0.5])

# %%
f
# Out:
# array([[-0. , -0.5, -1. , ...,  1.5,  1. ,  0.5]])

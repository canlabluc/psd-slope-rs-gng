# %%
# %matplotlib inline
import os
import glob
import datetime
import seaborn as sns
import numpy as np
import scipy as sp
import pandas as pd
import scipy.io
import numpy.fft
import scipy.signal
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.stats import linregress
from sklearn import linear_model
mpl.rcParams['figure.figsize'] = (16, 10)

# %%
def get_filelist(import_path):
    matfiles = []
    for root, dirs, files in os.walk(import_path):
        matfiles += glob.glob(os.path.join(root, '*.mat'))
    return matfiles

def import_subject(subj, i, import_path):
    """ 
    Imports a single subject and adds them to the subj
    data structure. Additionally, merges 
    """
    subj[i] = {}
    datafile = sp.io.loadmat(import_path)
    subj[i]['name'] = str(np.squeeze(datafile['name']))
    subj[i]['srate'] = int(np.squeeze(datafile['srate']))
    subj[i]['events'] = []
    for event in np.squeeze(datafile['evts']):
        subj[i]['events'].append([event[0][0], event[1][0][0], event[2][0][0]])
    subj[i]['data'] = np.squeeze(datafile['data'])
    subj[i]['nbchan'] = len(subj[i]['data'])
    return subj

def _print_window_info(events, port_code):
    evts = [[events[i][1], events[i+1][1]] for i in range(len(events)) if events[i][0] == port_code]
    total_wins = 0
    total_secs = 0
    for e in evts:
        if (e[1] - e[0]) >= 1024:
            pts  = e[1] - e[0]
            secs = (e[1] - e[0])//512
            nwin = (e[1] - e[0])//512 - 1
            total_wins += nwin
            total_secs += secs
            print('Event {}:\t{} points, {} seconds, {} windows'.format(e, pts, secs, nwin))
    print('Total windows able to be extracted: ', total_wins)

def get_windows(data, events, port_code, nperwindow=512*2, noverlap=512):
    windows = []
    # The following line restructures events of type port_code into the 
    # following format:
    #         [start_time, end_time]
    evts = [[events[i][1], events[i+1][1]] for i in range(len(events)) if events[i][0] == port_code]
    for event in evts:
        if event[1]-event[0] >= nperwindow:
            nwindows = (event[1] - event[0])//noverlap - 1
            for i in range(nwindows):
                windows.append(data[event[0] + noverlap*i : event[0] + noverlap*i + nperwindow])
    return windows

def welch(windows, srate):
    """
    Takes a list of data segments (each size 1xN), computes each segment's PSD,
    and averages them to get a final PSD.
    """
    psds = [sp.signal.welch(window, srate, nperseg=len(window), window='hamming')[1] for window in windows]
    return np.mean(psds, axis=0)

def remove_freq_buffer(data, lofreq, hifreq):
    """
    Removes a frequency buffer from a PSD or frequency vector.
    """
    data = np.delete(data, range(lofreq*2, hifreq*2))
    return data.reshape(len(data), 1)

def compute_subject_psds(import_path, import_path_csv):
    """ Returns subj data structure with calculated PSDs and subject information.
    Arguments:
        import_path:     String, path to .mat files
        import_path_csv: String, path to .csv containing subject class, sex, and
                         age information. 
    """
    matfiles = get_filelist(import_path)
    df = pd.read_csv(import_path_csv)
    df.SUBJECT = df.SUBJECT.astype(str)

    subj = {}
    subj['nbsubj'] = len(matfiles)
    subj['f'] = np.linspace(0, 256, 513)
    subj['f'] = subj['f'].reshape(len(subj['f']), 1)
    subj['f_rm_alpha'] = remove_freq_buffer(subj['f'], 7, 14)
    for i in range(len(matfiles)):
        
        subj = import_subject(subj, i, matfiles[i])
        subj[i]['age']   = df[df.SUBJECT == subj[i]['name']].AGE.values[0]
        subj[i]['class'] = df[df.SUBJECT == subj[i]['name']].CLASS.values[0]
        subj[i]['sex']   = df[df.SUBJECT == subj[i]['name']].SEX.values[0]

        for ch in range(subj[i]['nbchan']):
            subj[i][ch] = {}
            windows = get_windows(subj[i]['data'][ch], subj[i]['events'], 'C1')
            subj[i][ch]['psd'] = welch(windows, 512)
            subj[i][ch]['psd_rm_alpha'] = remove_freq_buffer(subj[i][ch]['psd'], 7, 14)
        subj[i]['data'] = np.nan # No longer needed, so clear it from memory
        subj[i]['psd'] = np.mean([subj[i][ch]['psd'] for ch in range(subj[i]['nbchan'])], axis=0)
        subj[i]['psd_rm_alpha'] = remove_freq_buffer(subj[i]['psd'], 7, 14)
        print("Processed: ", subj[i]['name'])
    subj['psd'] = np.mean([subj[i]['psd'] for i in range(subj['nbsubj'])], axis=0)
    return subj

# %%
subjoa = np.load('../../data/GoNoGo/2016-10-22-22:43:12.989774/subjoa-2-24-ransac.npy').item()

# %%
matfiles = get_filelist('../../data/GoNoGo/oaExclFiltCARClust-mat/')
df = pd.read_csv('../../data/GoNoGo/ya-oa-gng.csv')

# %%
subj = {}
datafile = sp.io.loadmat('../../data/GoNoGo/oaExclFiltCARClust-mat/120132101.mat')
subj['name'] = str(np.squeeze(datafile['name']))
subj['srate'] = int(np.squeeze(datafile['srate']))
subj['events'] = []
for event in np.squeeze(datafile['evts']):
    subj['events'].append([event[0][0], event[1][0][0], event[2][0][0]])
subj['data'] = np.squeeze(datafile['data'])
subj['nbchan'] = len(subj['data'])
# return subj

# %%
_print_window_info(subj['events'], 'C1')
# Out:
# Event [207252, 210038]:	2786 points, 5 seconds, 4 windows
# Event [210243, 211669]:	1426 points, 2 seconds, 1 windows
# Event [211874, 214984]:	3110 points, 6 seconds, 5 windows
# Event [216851, 218752]:	1901 points, 3 seconds, 2 windows
# Event [222591, 223875]:	1284 points, 2 seconds, 1 windows
# Event [235627, 236937]:	1310 points, 2 seconds, 1 windows
# Event [237202, 238249]:	1047 points, 2 seconds, 1 windows
# Event [238454, 239562]:	1108 points, 2 seconds, 1 windows
# Event [241102, 242787]:	1685 points, 3 seconds, 2 windows
# Event [243275, 245174]:	1899 points, 3 seconds, 2 windows
# Event [245632, 247432]:	1800 points, 3 seconds, 2 windows
# Event [249558, 251427]:	1869 points, 3 seconds, 2 windows
# Event [252053, 253372]:	1319 points, 2 seconds, 1 windows
# Event [257785, 258879]:	1094 points, 2 seconds, 1 windows
# Event [259084, 260132]:	1048 points, 2 seconds, 1 windows
# Event [260588, 263446]:	2858 points, 5 seconds, 4 windows
# Event [265523, 267061]:	1538 points, 3 seconds, 2 windows
# Event [270006, 271786]:	1780 points, 3 seconds, 2 windows
# Event [274285, 275695]:	1410 points, 2 seconds, 1 windows
# Event [275787, 277315]:	1528 points, 2 seconds, 1 windows
# Event [279576, 281453]:	1877 points, 3 seconds, 2 windows
# Event [286006, 287383]:	1377 points, 2 seconds, 1 windows
# Event [287588, 288933]:	1345 points, 2 seconds, 1 windows
# Event [294729, 296674]:	1945 points, 3 seconds, 2 windows
# Event [299082, 301177]:	2095 points, 4 seconds, 3 windows
# Event [303506, 305748]:	2242 points, 4 seconds, 3 windows
# Event [311728, 313837]:	2109 points, 4 seconds, 3 windows
# Event [317843, 320141]:	2298 points, 4 seconds, 3 windows
# Event [324466, 327240]:	2774 points, 5 seconds, 4 windows
# Event [327445, 329662]:	2217 points, 4 seconds, 3 windows
# Event [333913, 336097]:	2184 points, 4 seconds, 3 windows
# Event [336302, 337636]:	1334 points, 2 seconds, 1 windows
# Event [342616, 343772]:	1156 points, 2 seconds, 1 windows
# Event [346222, 348203]:	1981 points, 3 seconds, 2 windows
# Event [348722, 349958]:	1236 points, 2 seconds, 1 windows
# Event [350121, 351645]:	1524 points, 2 seconds, 1 windows
# Event [351850, 353616]:	1766 points, 3 seconds, 2 windows
# Event [358766, 360079]:	1313 points, 2 seconds, 1 windows
# Event [361356, 363574]:	2218 points, 4 seconds, 3 windows
# Event [365593, 367384]:	1791 points, 3 seconds, 2 windows
# Event [369916, 370943]:	1027 points, 2 seconds, 1 windows
# Event [372192, 373607]:	1415 points, 2 seconds, 1 windows
# Event [380352, 382491]:	2139 points, 4 seconds, 3 windows
# Event [392954, 395205]:	2251 points, 4 seconds, 3 windows
# Event [396904, 400791]:	3887 points, 7 seconds, 6 windows
# Event [400996, 404420]:	3424 points, 6 seconds, 5 windows
# Event [408371, 411310]:	2939 points, 5 seconds, 4 windows
# Event [411515, 413079]:	1564 points, 3 seconds, 2 windows
# Event [418219, 419248]:	1029 points, 2 seconds, 1 windows
# Event [421267, 422449]:	1182 points, 2 seconds, 1 windows
# Event [423088, 424168]:	1080 points, 2 seconds, 1 windows
# Event [425850, 427917]:	2067 points, 4 seconds, 3 windows
# Event [435184, 436363]:	1179 points, 2 seconds, 1 windows
# Event [436451, 437787]:	1336 points, 2 seconds, 1 windows
# Event [437992, 439768]:	1776 points, 3 seconds, 2 windows
# Event [442924, 444260]:	1336 points, 2 seconds, 1 windows
# Event [446212, 447333]:	1121 points, 2 seconds, 1 windows
# Event [451901, 453234]:	1333 points, 2 seconds, 1 windows
# Event [453439, 455407]:	1968 points, 3 seconds, 2 windows
# Event [456606, 458187]:	1581 points, 3 seconds, 2 windows
# Event [463686, 465622]:	1936 points, 3 seconds, 2 windows
# Event [465827, 467100]:	1273 points, 2 seconds, 1 windows
# Event [468655, 469724]:	1069 points, 2 seconds, 1 windows
# Event [470378, 471467]:	1089 points, 2 seconds, 1 windows
# Event [480225, 482508]:	2283 points, 4 seconds, 3 windows
# Event [488298, 489813]:	1515 points, 2 seconds, 1 windows
# Event [498487, 500364]:	1877 points, 3 seconds, 2 windows
# Event [500761, 501807]:	1046 points, 2 seconds, 1 windows
# Event [502012, 503774]:	1762 points, 3 seconds, 2 windows
# Event [504989, 506322]:	1333 points, 2 seconds, 1 windows
# Event [507451, 509722]:	2271 points, 4 seconds, 3 windows
# Event [509971, 511437]:	1466 points, 2 seconds, 1 windows
# Event [512771, 514691]:	1920 points, 3 seconds, 2 windows
# Event [517702, 519369]:	1667 points, 3 seconds, 2 windows
# Event [523988, 525620]:	1632 points, 3 seconds, 2 windows
# Event [526565, 527754]:	1189 points, 2 seconds, 1 windows
# Event [539524, 540619]:	1095 points, 2 seconds, 1 windows
# Event [540824, 542040]:	1216 points, 2 seconds, 1 windows
# Event [544317, 545750]:	1433 points, 2 seconds, 1 windows
# Event [548553, 550827]:	2274 points, 4 seconds, 3 windows
# Event [552039, 553309]:	1270 points, 2 seconds, 1 windows
# Event [557642, 558927]:	1285 points, 2 seconds, 1 windows
# Event [560770, 562192]:	1422 points, 2 seconds, 1 windows
# Event [565597, 568616]:	3019 points, 5 seconds, 4 windows
# Event [577724, 578754]:	1030 points, 2 seconds, 1 windows
# Total windows able to be extracted:  161

# %%
subj['events']
# Out:
# [['C1', 207252, 1],
#  ['C2', 210038, 2],
#  ['C1', 210243, 3],
#  ['C2', 211669, 4],
#  ['C1', 211874, 5],
#  ['C2', 214984, 6],
#  ['C1', 216851, 7],
#  ['C2', 218752, 8],
#  ['C1', 222591, 9],
#  ['C2', 223875, 10],
#  ['C1', 235627, 11],
#  ['C2', 236937, 12],
#  ['C1', 237202, 13],
#  ['C2', 238249, 14],
#  ['C1', 238454, 15],
#  ['C2', 239562, 16],
#  ['C1', 241102, 17],
#  ['C2', 242787, 18],
#  ['C1', 243275, 19],
#  ['C2', 245174, 20],
#  ['C1', 245632, 21],
#  ['C2', 247432, 22],
#  ['C1', 249558, 23],
#  ['C2', 251427, 24],
#  ['C1', 252053, 25],
#  ['C2', 253372, 26],
#  ['C1', 257785, 27],
#  ['C2', 258879, 28],
#  ['C1', 259084, 29],
#  ['C2', 260132, 30],
#  ['C1', 260588, 31],
#  ['C2', 263446, 32],
#  ['C1', 265523, 33],
#  ['C2', 267061, 34],
#  ['C1', 270006, 35],
#  ['C2', 271786, 36],
#  ['C1', 274285, 37],
#  ['C2', 275695, 38],
#  ['C1', 275787, 39],
#  ['C2', 277315, 40],
#  ['C1', 279576, 41],
#  ['C2', 281453, 42],
#  ['C1', 286006, 43],
#  ['C2', 287383, 44],
#  ['C1', 287588, 45],
#  ['C2', 288933, 46],
#  ['C1', 294729, 47],
#  ['C2', 296674, 48],
#  ['C1', 299082, 49],
#  ['C2', 301177, 50],
#  ['C1', 303506, 51],
#  ['C2', 305748, 52],
#  ['C1', 311728, 53],
#  ['C2', 313837, 54],
#  ['C1', 317843, 55],
#  ['C2', 320141, 56],
#  ['C1', 324466, 57],
#  ['C2', 327240, 58],
#  ['C1', 327445, 59],
#  ['C2', 329662, 60],
#  ['C1', 333913, 61],
#  ['C2', 336097, 62],
#  ['C1', 336302, 63],
#  ['C2', 337636, 64],
#  ['C1', 342616, 65],
#  ['C2', 343772, 66],
#  ['C1', 346222, 67],
#  ['C2', 348203, 68],
#  ['C1', 348722, 69],
#  ['C2', 349958, 70],
#  ['C1', 350121, 71],
#  ['C2', 351645, 72],
#  ['C1', 351850, 73],
#  ['C2', 353616, 74],
#  ['C1', 358766, 75],
#  ['C2', 360079, 76],
#  ['C1', 361356, 77],
#  ['C2', 363574, 78],
#  ['C1', 365593, 79],
#  ['C2', 367384, 80],
#  ['C1', 369916, 81],
#  ['C2', 370943, 82],
#  ['C1', 372192, 83],
#  ['C2', 373607, 84],
#  ['C1', 380352, 85],
#  ['C2', 382491, 86],
#  ['C1', 392954, 87],
#  ['C2', 395205, 88],
#  ['C1', 396904, 89],
#  ['C2', 400791, 90],
#  ['C1', 400996, 91],
#  ['C2', 404420, 92],
#  ['C1', 408371, 93],
#  ['C2', 411310, 94],
#  ['C1', 411515, 95],
#  ['C2', 413079, 96],
#  ['C1', 418219, 97],
#  ['C2', 419248, 98],
#  ['C1', 421267, 99],
#  ['C2', 422449, 100],
#  ['C1', 423088, 101],
#  ['C2', 424168, 102],
#  ['C1', 425850, 103],
#  ['C2', 427917, 104],
#  ['C1', 435184, 105],
#  ['C2', 436363, 106],
#  ['C1', 436451, 107],
#  ['C2', 437787, 108],
#  ['C1', 437992, 109],
#  ['C2', 439768, 110],
#  ['C1', 442924, 111],
#  ['C2', 444260, 112],
#  ['C1', 446212, 113],
#  ['C2', 447333, 114],
#  ['C1', 451901, 115],
#  ['C2', 453234, 116],
#  ['C1', 453439, 117],
#  ['C2', 455407, 118],
#  ['C1', 456606, 119],
#  ['C2', 458187, 120],
#  ['C1', 463686, 121],
#  ['C2', 465622, 122],
#  ['C1', 465827, 123],
#  ['C2', 467100, 124],
#  ['C1', 468655, 125],
#  ['C2', 469724, 126],
#  ['C1', 470378, 127],
#  ['C2', 471467, 128],
#  ['C1', 480225, 129],
#  ['C2', 482508, 130],
#  ['C1', 488298, 131],
#  ['C2', 489813, 132],
#  ['C1', 498487, 133],
#  ['C2', 500364, 134],
#  ['C1', 500761, 135],
#  ['C2', 501807, 136],
#  ['C1', 502012, 137],
#  ['C2', 503774, 138],
#  ['C1', 504989, 139],
#  ['C2', 506322, 140],
#  ['C1', 507451, 141],
#  ['C2', 509722, 142],
#  ['C1', 509971, 143],
#  ['C2', 511437, 144],
#  ['C1', 512771, 145],
#  ['C2', 514691, 146],
#  ['C1', 517702, 147],
#  ['C2', 519369, 148],
#  ['C1', 523988, 149],
#  ['C2', 525620, 150],
#  ['C1', 526565, 151],
#  ['C2', 527754, 152],
#  ['C1', 539524, 153],
#  ['C2', 540619, 154],
#  ['C1', 540824, 155],
#  ['C2', 542040, 156],
#  ['C1', 544317, 157],
#  ['C2', 545750, 158],
#  ['C1', 548553, 159],
#  ['C2', 550827, 160],
#  ['C1', 552039, 161],
#  ['C2', 553309, 162],
#  ['C1', 557642, 163],
#  ['C2', 558927, 164],
#  ['C1', 560770, 165],
#  ['C2', 562192, 166],
#  ['C1', 565597, 167],
#  ['C2', 568616, 168],
#  ['C1', 577724, 169],
#  ['C2', 578754, 170]]
